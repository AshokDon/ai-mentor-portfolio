# %% [markdown]
# <a href="https://colab.research.google.com/github/AshokDon/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the necessary competencies for successful AI development and deployment, from foundational to strategic:
#
# *   **Layer 1: Data & Infrastructure:** The base, focusing on data collection, cleaning, storage, processing, and the underlying computational resources (cloud, GPUs).
# *   **Layer 2: Machine Learning Fundamentals:** Core skills in algorithms, model training, evaluation, feature engineering, and understanding various ML techniques.
# *   **Layer 3: Application & Domain Expertise:** Applying ML models to solve real-world problems within specific industries, requiring deep understanding of the problem space and integration into products.
# *   **Layer 4: Ethical & Responsible AI:** Ensuring AI systems are fair, transparent, secure, unbiased, and used responsibly, addressing societal impacts and regulatory compliance.
# *   **Layer 5: Strategic Vision & Innovation:** The apex, focusing on how AI drives business value, fosters innovation, leads to human-AI collaboration, and shapes organizational strategy.
